# %% [markdown]
# # Problem statement 7:
# Create a Linear Regression Model using Python/R to predict home prices.The
# objective is to predict the value of prices of the house using the given features in
# the dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("boston-housing-dataset.csv")

# %%
df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#        TAX  PTRATIO       B  LSTAT  MEDV
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#      TAX  PTRATIO       B  LSTAT  MEDV
# 0  296.0     15.3  396.90   4.98  24.0
# 1  242.0     17.8  396.90   9.14  21.6
# 2  242.0     17.8  392.83   4.03  34.7
# 3  222.0     18.7  394.63   2.94  33.4
# 4  222.0     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#      Unnamed: 0     CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 501         501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#        TAX  PTRATIO       B  LSTAT  MEDV
# 501  273.0     21.0  391.99   9.67  22.4
# 502  273.0     21.0  396.90   9.08  20.6
# 503  273.0     21.0  396.90   5.64  23.9
# 504  273.0     21.0  393.45   6.48  22.0
# 505  273.0     21.0  396.90   7.88  11.9

# %%
len(df)
# Out:
# 506

# %%
df.shape
# Out:
# (506, 15)

# %%
df.isna()
# Out:
#      Unnamed: 0   CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS  \
# 0         False  False  False  False  False  False  False  False  False
# 1         False  False  False  False  False  False  False  False  False
# 2         False  False  False  False  False  False  False  False  False
# 3         False  False  False  False  False  False  False  False  False
# 4         False  False  False  False  False  False  False  False  False
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501       False  False  False  False  False  False  False  False  False
# 502       False  False  False  False  False  False  False  False  False
# 503       False  False  False  False  False  False  False  False  False
# 504       False  False  False  False  False  False  False  False  False
# 505       False  False  False  False  False  False  False  False  False
#
#        RAD    TAX  PTRATIO      B  LSTAT   MEDV
# 0    False  False    False  False  False  False
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# CRIM          0
# ZN            0
# INDUS         0
# CHAS          0
# NOX           0
# RM            0
# AGE           0
# DIS           0
# RAD           0
# TAX           0
# PTRATIO       0
# B             0
# LSTAT         0
# MEDV          0
# dtype: int64

# %%
sns.histplot(data=df, x="MEDV", bins=30, kde=True)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='Count'>

# %%
correlation_matrix = df.corr().round(2)
correlation_matrix
# Out:
#             Unnamed: 0  CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD  \
# Unnamed: 0        1.00  0.41 -0.10   0.40 -0.00  0.40 -0.08  0.20 -0.30  0.69
# CRIM              0.41  1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63
# ZN               -0.10 -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31
# INDUS             0.40  0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60
# CHAS             -0.00 -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01
# NOX               0.40  0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61
# RM               -0.08 -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21
# AGE               0.20  0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46
# DIS              -0.30 -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49
# RAD               0.69  0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00
# TAX               0.67  0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91
# ...

# %%
sns.set(rc={"figure.figsize":(10, 8)})
sns.heatmap(correlation_matrix, annot=True, cmap="Spectral")
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={"figure.figsize":(8, 6)})
sns.scatterplot(x=df["LSTAT"], y=df["MEDV"])
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>

# %%
sns.scatterplot(x=df["RM"], y=df["MEDV"])
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
X = df[["LSTAT", "RM"]]
y = df["MEDV"]

# %%
print("X Shape: ", X.shape)
# Out:
# X Shape:  (506, 2)

# %%
print("y Shape:", y.shape)
# Out:
# y Shape: (506,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print("X_train Shape: ", X_train.shape)
print("y_train Shape: ", y_train.shape)
print("X_test Shape: ", X_test.shape)
print("y_test Shape: ", y_test.shape)
# Out:
# X_train Shape:  (404, 2)
# y_train Shape:  (404,)
# X_test Shape:  (102, 2)
# y_test Shape:  (102,)

# %%
from sklearn.linear_model import LinearRegression

linear_regressor = LinearRegression()
linear_regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
# Accuracy Metrics on Training Data
y_train_predict = linear_regressor.predict(X_train)

mae_train = mean_absolute_error(y_train, y_train_predict)
r2_train = r2_score(y_train, y_train_predict)
mse_train = mean_squared_error(y_train, y_train_predict)

print("Mean Absolute Error for Training Data: {}".format(round(mae_train, 2)))
print("R2 Score for Training Data: {}%".format(round(r2_train, 2)*100))
print("Mean Square Error for Training Data: {}".format(round(mse_train, 2)))
# Out:
# Mean Absolute Error for Training Data: 4.02
# R2 Score for Training Data: 62.0%
# Mean Square Error for Training Data: 31.67

# %%
# Accuracy Metrics on Test Data
y_test_predict = linear_regressor.predict(X_test)

mae_test = mean_absolute_error(y_test, y_test_predict)
r2_test = r2_score(y_test, y_test_predict)
mse_test = mean_squared_error(y_test, y_test_predict)

print("Mean Absolute Error for Test Data: {}".format(round(mae_test, 2)))
print("R2 Score for Test Data: {}%".format(round(r2_test, 2)*100))
print("Mean Squared Error for Test Data: {}".format(round(mse_test, 2)))
# Out:
# Mean Absolute Error for Test Data: 3.64
# R2 Score for Test Data: 71.0%
# Mean Squared Error for Test Data: 25.96
